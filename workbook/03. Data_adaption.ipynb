# %% [markdown]
# # 3. Data adaption
#
# ## While using Tableau, some additinoal data cleanings are needed.

# %%
import pandas as pd
import datetime

# %% [markdown]
# #### Cross-check the "all_time_available" filter, as some arrival time are missing, altought the filter indicates the opposite.

# %%
df = pd.read_pickle("/Users/Tianwang/ironhack/git/03_project_ironhack_tableau/data/baton_rouge_animal_control_incidents_clean_update.pkl")

# %%
df.head()
# Out:
#    file_number incident_date complainant_street             location  \
# 0    201639027    12/27/2016        SYCAMORE ST        3366 SYCAMORE
# 1    201639044    12/28/2016  WOODLAND RIDGE BL  2582 WOODLAND RIDGE
# 2    201639036    12/28/2016            MAIN ST            4463 MAIN
# 3    201639042    12/28/2016            ERIE ST            2100 ERIE
# 4    201639059    12/28/2016       VAN BUREN ST        299 VAN BUREN
#
#   municipality zip_code       service_code   species              breed  \
# 0  BATON ROUGE    70805              LOOSE       DOG            PITBULL
# 1  BATON ROUGE    70816     TRAPPED ANIMAL  WILDLIFE             POSSUM
# 2      ZACHARY    70791  STRAY AND SECURED       DOG            PITBULL
# 3  BATON ROUGE    70805   ABANDONED ANIMAL       DOG    GERMAN SHEPHERD
# 4  BATON ROUGE    70714              STRAY       DOG  YORKSHIRE TERRIER
#
#    condition  ...    arrival_time_new  available_time_new   incident_time_new  \
# 0       FAIR  ... 2016-12-27 16:17:00 2016-12-27 16:38:00 2016-12-27 15:30:00
# 1       FAIR  ... 2016-12-28 10:15:00 2016-12-28 10:23:00 2016-12-28 10:06:00
# 2  EMACIATED  ... 2016-12-28 09:27:00 2016-12-28 09:45:00 2016-12-28 09:03:00
# 3  EMACIATED  ... 2016-12-28 10:35:00 2016-12-28 10:47:00 2016-12-28 09:46:00
# 4  EMACIATED  ... 2016-12-28 16:07:00 2016-12-28 16:25:00 2016-12-28 15:05:00
#
#   dispatched_time_new all_time_available incident_to_dispatch  \
# 0 2016-12-27 16:06:00                Yes                 36.0
# 1 2016-12-28 10:07:00                Yes                  1.0
# 2 2016-12-28 09:03:00                Yes                  0.0
# 3 2016-12-28 10:24:00                Yes                 38.0
# 4 2016-12-28 15:45:00                Yes                 40.0
#
#    disp_to_arrival  service_code_summary species_clean  \
# 0             11.0                 LOOSE           DOG
# 1              8.0        TRAPPED ANIMAL      WILDLIFE
# 2             24.0                 STRAY           DOG
# 3             11.0      ABANDONED ANIMAL           DOG
# 4             22.0                 STRAY           DOG
#
#                               clean_adress
# 0        3366 SYCAMORE, BATON ROUGE, 70805
# 1  2582 WOODLAND RIDGE, BATON ROUGE, 70816
# 2                4463 MAIN, ZACHARY, 70791
# 3            2100 ERIE, BATON ROUGE, 70805
# 4        299 VAN BUREN, BATON ROUGE, 70714
#
# [5 rows x 21 columns]

# %%
df_time_available = df[df["all_time_available"]=="Yes"]

# %%
df_time_available.loc[df_time_available["incident_time_new"].isna()]
# Out:
# Empty DataFrame
# Columns: [file_number, incident_date, complainant_street, location, municipality, zip_code, service_code, species, breed, condition, temperment, arrival_time_new, available_time_new, incident_time_new, dispatched_time_new, all_time_available, incident_to_dispatch, disp_to_arrival, service_code_summary, species_clean, clean_adress]
# Index: []
#
# [0 rows x 21 columns]

# %%
df = pd.read_csv("/Users/Tianwang/ironhack/git/03_project_ironhack_tableau/data/raw_data_Animal_Control_Incidents.csv")

# %%
pd.to_datetime(df["INCIDENT TIME"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/envs/backpack_banana/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1857         try:
# -> 1858             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    1859             # If tzaware, these values represent unix timestamps, so we
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# OutOfBoundsDatetime                       Traceback (most recent call last)
# <ipython-input-35-220b487a35dd> in <module>
# ----> 1 pd.to_datetime(df["INCIDENT TIME"])
#
# ~/anaconda3/envs/backpack_banana/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     722                 result = result.tz_localize(tz)
#     723     elif isinstance(arg, ABCSeries):
# --> 724         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#     725         if not cache_array.empty:
#     726             result = arg.map(cache_array)
#
# ~/anaconda3/envs/backpack_banana/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in _maybe_cache(arg, format, cache, convert_listlike)
#     150         unique_dates = unique(arg)
#     151         if len(unique_dates) < len(arg):
# --> 152             cache_dates = convert_listlike(unique_dates, format)
#     153             cache_array = Series(cache_dates, index=unique_dates)
#     154     return cache_array
#
# ~/anaconda3/envs/backpack_banana/lib/python3.7/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     445             errors=errors,
#     446             require_iso8601=require_iso8601,
# --> 447             allow_object=True,
#     448         )
#     449
#
# ~/anaconda3/envs/backpack_banana/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1861             return values.view("i8"), tz_parsed
#    1862         except (ValueError, TypeError):
# -> 1863             raise e
#    1864
#    1865     if tz_parsed is not None:
#
# ~/anaconda3/envs/backpack_banana/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1852             dayfirst=dayfirst,
#    1853             yearfirst=yearfirst,
# -> 1854             require_iso8601=require_iso8601,
#    1855         )
#    1856     except ValueError as e:
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.convert_datetime_to_tsobject()
#
# pandas/_libs/tslibs/np_datetime.pyx in pandas._libs.tslibs.np_datetime.check_dts_bounds()
#
# OutOfBoundsDatetime: Out of bounds nanosecond timestamp: 1-01-01 08:06:00
